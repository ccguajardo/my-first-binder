# %% [markdown]
# # Problema 1
# ## Parte 1:

# %%
using Statistics
A=[1,10,33,5,8,13,17];
B=round(mean(A), digits=5);
C=round(std(A), digits=5);

println("La media y desviación estándar del vector "*string(A')*" es "*string(B)*" y "*string(C)*" respectivamente.")
# Out:
# La media y desviación estándar del vector [1 10 33 5 8 13 17] es 12.42857 y 10.45398 respectivamente.

# %% [markdown]
# #### Se importan las librerías

# %%
using Pkg;
Pkg.add("DataFrames");
Pkg.add("XLSX");
Pkg.add("Plots");
# Out:
#    Resolving package versions...
#   No Changes to `~/Project.toml`
#   No Changes to `~/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/Project.toml`
#   No Changes to `~/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/Project.toml`
#   No Changes to `~/Manifest.toml`

# %%
using XLSX
using Plots

data_p1 = XLSX.readxlsx("datos_p1.xlsx")
hoja_1 = data_p1[hoja_datos"]
a11= hoja_1["B3:B9"]
a1= Array{Float64}(XLSX.readdata("datos_p1.xlsx","hoja_datos!B3:B9"))
mean_a1= round(mean(a1),digits=2);
std_a1 = std(a1)

v1=[]
for i=1:size(a1)[1]
    push!(v1,mean_a1)
end

plot([1:7],[a1 Array{Float64}(v1)])
a11

# %%
a1
# Out:
# 7×1 Matrix{Float64}:
#   1.0
#  10.0
#  33.0
#   5.0
#   8.0
#  13.0
#  17.0
